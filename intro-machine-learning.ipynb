# %%
# features (1 sim, 0 não)
# pelo longo
# perna curta
# late
porco1 = [0, 1, 0]
porco2 = [0, 1, 1]
porco3 = [1, 1, 0]

cachorro1 = [0, 1, 1]
cachorro2 = [1, 0, 1]
cachorro3 = [1, 1, 1]

# 1 é porco e 0 é cachorro
treino_x = [porco1, porco2, porco3, cachorro1, cachorro2, cachorro3]
treino_y = [1, 1, 1, 0, 0, 0] #labels

# %%
from sklearn.svm import LinearSVC

model = LinearSVC()
model.fit(treino_x, treino_y)
# Out:
# LinearSVC()

# %%
animal_misterioso = [1, 1, 1]
model.predict([animal_misterioso])
# Out:
# array([0])

# %%
misterio1 = [1, 1, 1]
misterio2 = [1, 1, 0]
misterio3 = [0, 1, 1]

teste_x = [misterio1, misterio2, misterio3]
teste_y = [0, 1, 1]

# %%
previsoes = model.predict(teste_x)

# %%
corretos = (previsoes == teste_y).sum()
corretos
# Out:
# 2

# %%
total = len(teste_x)
taxa_acerto = corretos/total
print("taxa de acerto: %.2f" %(taxa_acerto * 100))
# Out:
# taxa de acerto: 66.67

# %%
from sklearn.metrics import accuracy_score

# %%
taxa_acerto = accuracy_score(teste_y, previsoes)

# %%
print("taxa de acerto %.2f" % (taxa_acerto *100))
# Out:
# taxa de acerto 66.67

# %%
#A maneira correta para treinar um algoritmo:
# 1. Definir um modelo de treino
# 2. Definir uma lista com dados para treino e dados com os resultados esperados
# 3. Treinar com base na lista de dados e nos resultados esperados
